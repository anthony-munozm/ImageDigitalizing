# %%
import pandas as pd
import numpy as np
import datetime
from dateutil.relativedelta import relativedelta
from datetime import date
import datetime as dt
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
name = "Estimated Suppression for 1M USD LIBOR.csv"
name = "Estimated Suppression for 1W USD LIBOR.csv"
name = "Estimated Suppression for 2M USD LIBOR.csv"
name = "Estimated Suppression for 2W USD LIBOR.csv"
name = "Estimated Suppression for 3M USD LIBOR.csv"
name = "Estimated Suppression for 4M USD LIBOR.csv"
name = "Estimated Suppression for 5M USD LIBOR.csv"
name = "Estimated Suppression for 6M USD LIBOR.csv"
name = "Estimated Suppression for 7M USD LIBOR.csv"
name = "Estimated Suppression for 8M USD LIBOR.csv"
name = "Estimated Suppression for 9M USD LIBOR.csv"
name = "Estimated Suppression for 10M USD LIBOR.csv"
name = "Estimated Suppression for 11M USD LIBOR.csv"
name = "Estimated Suppression for 12M USD LIBOR.csv"

# %% [markdown]
# # Estimated Suppression for 1M USD LIBOR.csv

# %%
name = "Estimated Suppression for 1M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]

# %%
General = data

# %% [markdown]
# # Estimated Suppression for 1W USD LIBOR.csv

# %%
name = "Estimated Suppression for 1W USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 2M USD LIBOR.csv

# %%
name = "Estimated Suppression for 2M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 2W USD LIBOR.csv

# %%
name = "Estimated Suppression for 2W USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 3M USD LIBOR.csv

# %%
name = "Estimated Suppression for 3M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 4M USD LIBOR.csv

# %%
name = "Estimated Suppression for 4M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 5M USD LIBOR.csv

# %%
name = "Estimated Suppression for 5M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 6M USD LIBOR.csv

# %%
name = "Estimated Suppression for 6M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 7M USD LIBOR.csv

# %%
name = "Estimated Suppression for 7M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 8M USD LIBOR.csv

# %%
name = "Estimated Suppression for 8M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 9M USD LIBOR.csv

# %%
name = "Estimated Suppression for 9M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 10M USD LIBOR.csv

# %%
name = "Estimated Suppression for 10M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 11M USD LIBOR.csv

# %%
name = "Estimated Suppression for 11M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %% [markdown]
# # Estimated Suppression for 12M USD LIBOR.csv

# %%
name = "Estimated Suppression for 12M USD LIBOR.csv"
data = pd.read_csv(name,  header=None)
data = data[data[1]>0.05]
data = data[data[0]>1]
data = data[data[1]<2.45]
a = dt.datetime(2007,8,1,0,0,0)
b = dt.datetime(2010,5,1,0,0,0)
pd.set_option('display.float_format', '{:.2f}'.format)
data["date"] = pd.date_range(start='2007-8-1 00:00:00', end='2010-5-31 00:00:00', periods=len(data))
data["epoch"] = int(dt.datetime(2007,8,1,0,0,0).strftime('%s')) + data[0]*(b-a).total_seconds()/data[0].values[-1]
data['date_string'] = pd.to_datetime(data["epoch"], unit='s')
data.plot.line(x="date_string", y=1, figsize=(20,10))
data["identifier"] = name
data = data.rename(columns={1:"value"})
data= data[["value","identifier","date_string"]]
General = General.append(data)

# %%
General
# Out:
#       value                                   identifier  \
# 5      0.72   Estimated Suppression for 1M USD LIBOR.csv
# 6      0.72   Estimated Suppression for 1M USD LIBOR.csv
# 7      0.71   Estimated Suppression for 1M USD LIBOR.csv
# 15     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 16     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 17     0.71   Estimated Suppression for 1M USD LIBOR.csv
# 19     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 20     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 21     0.71   Estimated Suppression for 1M USD LIBOR.csv
# 23     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 24     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 25     0.71   Estimated Suppression for 1M USD LIBOR.csv
# 27     0.73   Estimated Suppression for 1M USD LIBOR.csv
# 28     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 29     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 31     0.73   Estimated Suppression for 1M USD LIBOR.csv
# 32     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 33     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 35     0.73   Estimated Suppression for 1M USD LIBOR.csv
# 36     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 37     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 39     0.73   Estimated Suppression for 1M USD LIBOR.csv
# 40     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 41     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 43     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 44     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 45     0.71   Estimated Suppression for 1M USD LIBOR.csv
# 47     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 48     0.72   Estimated Suppression for 1M USD LIBOR.csv
# 49     0.71   Estimated Suppression for 1M USD LIBOR.csv
# ...     ...                                          ...
# 4882   0.71  Estimated Suppression for 12M USD LIBOR.csv
# 4884   0.72  Estimated Suppression for 12M USD LIBOR.csv
# 